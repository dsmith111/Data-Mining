# %%
#Q3: The Mauna Loa Observatory has been measuring the average CO2 level (in ppm) in the atmosphere for several decades.
#Using simple linear regression, predict the CO2 levels in 2020.
#This is known as the Keeling curve.  
#Compare your prediction to recent measurements, and discuss the results.
#Finally, fill in the missing data to 2020 and predict the CO2 level in 2030.

# %%
#Learn
    #Randomize the value of m.
    #Give the variables to a loss function to determine error rate.
    #Adjust the value of m and b based on the error rate.
    #Go back to Step 2. Repeat until the variables stop changing.
    
#Loss Function
    #For each year
        #compare the predicted value y’ to actual value y to find the difference. 
        #Take average
        #Implement Gradient Descent to determine function

# %%
import numpy as np

class LinearRegression:

    def __init__(self, learning_rate=0.001, n_iters=1000):
        #self.lr = learning_rate #set learning rate for slower gradual updates
        #self.n_iters = n_iters
        #self.weights = np.random.rand(len(X))
        #self.bias = 0

    def train(self, X, y):
         gradient descent
        for _ in range(self.n_iters): #find derivatives and update weights at each iteration
            for n_samples, n_features, in zip(X,y): #combine to make iterable object
                y_predicted = np.dot(X, self.weights) + self.bias #y = mx+b
                # compute gradients - learn:
                dw = (1 / n_samples) * np.dot(X.T, (y_predicted - y)) #calculate error rate for weights
                db = (1 / n_samples) * np.sum(y_predicted - y) #calculate error rate for bias
            
                # update parameters
                self.weights -= self.lr * dw #apply learning rate
                self.bias -= self.lr * db #apply learning rate
 

    def predict(self, X):
        y_approximated = np.dot(X, self.weights) + self.bias
        return y_approximated
    
    def mean_squared_error(y, y_predicted):
        return np.mean((y - y_predicted)**2)
# Out:
#   File "<tokenize>", line 13
#     for _ in range(self.n_iters): #find derivatives and update weights at each iteration
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import numpy as np
import matplotlib.pyplot as plt

#Plot known data points
dataset = pd.DataFrame(np.array([[1980,338.7], [1982,341.1], [1984,344.4], [1986,347.2], [1988,351.5], [1990,354.2], [1992,356.4], [1994,358.9], [1996,362.6], [1998,366.6], [2000,369.4]]), columns=['Years', 'CO2 Level (ppm)'])

#dataset.plot(x='Years', y='CO2 Level (ppm)', style='o')
#plt.title('Years vs CO2 Level')
#plt.xlabel('Years')
#plt.ylabel('ppm')
#plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt #for plotting
from sklearn.linear_model import LinearRegression
import pandas as pd
from sklearn.metrics import mean_squared_error

X = dataset[['Years']]
y = dataset['CO2 Level (ppm)']

#X, y = dataset(n_samples=100, n_features=1, noise=20, random_state=0) #noise = bias and std. dev of the guassian noise, #random set for same data points for each run
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, train_size=0.75, random_state=0)

regressor = LinearRegression()
regressor.fit(X_train, y_train)
predictions = regressor.predict(X_test)
    
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)

y_pred_line = regressor.predict(X)
new_X = [[2020]]
print(regressor.predict(new_X))
cmap = plt.get_cmap('viridis')
fig = plt.figure(figsize=(8,6))
m1 = plt.scatter(X_train, y_train, color=cmap(0.9), s=10)
m2 = plt.scatter(X_test, y_test, color=cmap(0.5), s=10)
plt.plot(X, y_pred_line, color='black', linewidth=2, label="Prediction")
plt.show()
# Out:
# MSE: 0.5496895077476581
# [399.40178571]

# %%
y_pred_line = regressor.predict(X)
new_X = [[2020]]
new_Y = (regressor.predict(new_X))
new_X[0].insert(0, 1980)
new_X = new_X[0]
new_Y = np.insert(new_Y, 0, 340)
#print(new_X, new_Y)
cmap = plt.get_cmap('viridis')
fig = plt.figure(figsize=(6,6))
m1 = plt.scatter(X_train, y_train, color=cmap(0.9), s=10)
m2 = plt.scatter(X_test, y_test, color=cmap(0.5), s=10)
plt.plot(X, y_pred_line, color='black', linewidth=2, label="Prediction")
plt.plot(new_X, new_Y, color='blue', linewidth=2, label="Future Values")

plt.show()

# %%
#The current CO2 levels were last reported at 411 ppm. This means our model was slightly below target, this is something that could potentially be improved by adding more data or increasing the testing:training ratio.

# %%
#Plot known data points
dataset2020 = pd.DataFrame(np.array([[1980,338.7],
                                     [1982,341.1],
                                     [1984,344.4],
                                     [1986,347.2],
                                     [1988,351.5],
                                     [1990,354.2],
                                     [1992,356.4],
                                     [1994,358.9],
                                     [1996,362.6],
                                     [1998,366.6],
                                     [2000,369.4],
                                     [2002,373.3],
                                     [2004,377.5],
                                     [2006,381.9],
                                     [2008,385.6],
                                     [2010,389.9],
                                     [2012,391.7],
                                     [2014,393.9],
                                     [2016,398.4],
                                     [2018,408.5],
                                     [2020,411.3]]), columns=['Years', 'CO2 Level (ppm)'])


X = dataset2020[['Years']]
y = dataset2020['CO2 Level (ppm)']

#X, y = dataset(n_samples=100, n_features=1, noise=20, random_state=0) #noise = bias and std. dev of the guassian noise, #random set for same data points for each run
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, train_size=0.75, random_state=0)

regressor = LinearRegression()
regressor.fit(X_train, y_train)
predictions = regressor.predict(X_test)
    
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)

y_pred_line = regressor.predict(X)
new_X = [[2030]]
new_Y = (regressor.predict(new_X))
print(new_X, new_Y)
cmap = plt.get_cmap('viridis')
fig = plt.figure(figsize=(6,6))
m1 = plt.scatter(X_train, y_train, color=cmap(0.9), s=10)
m2 = plt.scatter(X_test, y_test, color=cmap(0.5), s=10)
plt.plot(X, y_pred_line, color='black', linewidth=2, label="Prediction")
plt.plot(new_X, new_Y, color='blue', linewidth=2, label="Future Values")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-df17077b641b> in <module>
#      33 predictions = regressor.predict(X_test)
#      34
# ---> 35 mse = mean_squared_error(y_test, predictions)
#      36 print("MSE:", mse)
#      37
#
# NameError: name 'mean_squared_error' is not defined
